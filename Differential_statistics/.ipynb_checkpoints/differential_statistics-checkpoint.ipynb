# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Data Overview

# %%
df = pd.read_csv('country_profile_variables.csv')
df.sample(5)
# Out:
#                               country         Region  Surface area (km2)  \
# 106                        Kazakhstan    CentralAsia           2724902.0
# 56   Democratic Republic of the Congo   MiddleAfrica           2344858.0
# 3                      American Samoa      Polynesia               199.0
# 115                           Liberia  WesternAfrica            111369.0
# 9                             Armenia    WesternAsia             29743.0
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 106                           18204                                 6.7
# 56                            81340                                35.9
# 3                                56                               278.2
# 115                            4732                                49.1
# 9                              2930                               102.9
#
#      Sex ratio (m per 100 f, 2017)  \
# 106                           93.9
# 56                            99.6
# 3                            103.6
# 115                          101.8
# 9                             88.8
#
#      GDP: Gross domestic product (million current US$)  \
# 106                                           181754.0
# 56                                             37569.0
# 3                                                871.0
# 115                                             2053.0
# 9                                              10529.0
#
#      GDP growth rate (annual %, const. 2005 prices)  \
# 106                                             1.2
# 56                                              7.0
# 3                                              -0.8
# 115                                             0.3
# 9                                               3.0
#
#      GDP per capita (current US$)  Unemployment (% of labour force)  \
# 106                       10312.1                               5.6
# 56                          486.2                               3.6
# 3                            69.5                               5.6
# 115                         455.9                               4.1
# 9                          3489.1                              16.6
#
#      International trade: Exports (million US$)  \
# 106                                       36775
# 56                                         5103
# 3                                          7852
# 115                                         641
# 9                                          1776
#
#      International trade: Imports (million US$)  \
# 106                                       25175
# 56                                         5906
# 3                                          7582
# 115                                         727
# 9                                          3230
#
#      Population growth rate (average annual %)  \
# 106                                        1.6
# 56                                         3.3
# 3                                          0.5
# 115                                        2.6
# 9                                          0.3
#
#      Urban population (% of total population)  \
# 106                                      53.2
# 56                                       42.5
# 3                                        87.2
# 115                                      49.7
# 9                                        62.7
#
#      Fertility rate, total (live births per woman)  \
# 106                                            2.7
# 56                                             6.4
# 3                                              2.6
# 115                                            4.8
# 9                                              1.6
#
#     Life expectancy at birth (females/males, years)
# 106                                       73.9/64.3
# 56                                        59.5/56.7
# 3                                         77.8/71.1
# 115                                       61.6/59.8
# 9                                         77.0/70.6

# %%
# Split the column into two new columns
df[['Life_Expectancy_Female', 'Life_Expectancy_Male']] = df['Life expectancy at birth (females/males, years)'].str.extract(r'([\d.]+)\s*/\s*([\d.]+)')

df['Life_Expectancy_Female'] = df['Life_Expectancy_Female'].astype(float)
df['Life_Expectancy_Male'] = df['Life_Expectancy_Male'].astype(float)

df.drop(columns=['Life expectancy at birth (females/males, years)'], inplace=True)

# %%
num_rows, num_columns = df.shape
print(f"Number of countries (rows)   : {num_rows}")
print(f"Number of columns (variables): {num_columns}")
# Out:
# Number of countries (rows)   : 229
# Number of columns (variables): 17

# %%
df.dtypes.value_counts()
# Out:
# float64    12
# int64       3
# object      2
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# country                                               object
# Region                                                object
# Surface area (km2)                                   float64
# Population in thousands (2017)                         int64
# Population density (per km2, 2017)                   float64
# Sex ratio (m per 100 f, 2017)                        float64
# GDP: Gross domestic product (million current US$)    float64
# GDP growth rate (annual %, const. 2005 prices)       float64
# GDP per capita (current US$)                         float64
# Unemployment (% of labour force)                     float64
# International trade: Exports (million US$)             int64
# International trade: Imports (million US$)             int64
# Population growth rate (average annual %)            float64
# Urban population (% of total population)             float64
# Fertility rate, total (live births per woman)        float64
# Life_Expectancy_Female                               float64
# Life_Expectancy_Male                                 float64
# dtype: object

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

print("Numerical Variables:")
print(numerical_cols)

print("\nCategorical Variables:")
print(categorical_cols)
# Out:
# Numerical Variables:
# ['Surface area (km2)', 'Population in thousands (2017)', 'Population density (per km2, 2017)', 'Sex ratio (m per 100 f, 2017)', 'GDP: Gross domestic product (million current US$)', 'GDP growth rate (annual %, const. 2005 prices)', 'GDP per capita (current US$)', 'Unemployment (% of labour force)', 'International trade: Exports (million US$)', 'International trade: Imports (million US$)', 'Population growth rate (average annual %)', 'Urban population (% of total population)', 'Fertility rate, total (live births per woman)', 'Life_Expectancy_Female', 'Life_Expectancy_Male']
#
# Categorical Variables:
# ['country', 'Region']

# %% [markdown]
# ## 2. Univariate Analysis

# %% [markdown]
# ### A. Numerical Variables

# %% [markdown]
# #### i. Central Tendency

# %%
central_tendency = df[numerical_cols].agg(['mean', 'median']).T
central_tendency.columns = ['Mean', 'Median']
central_tendency
# Out:
#                                                             Mean   Median
# Surface area (km2)                                 593677.879651  83600.0
# Population in thousands (2017)                      32756.794760   5448.0
# Population density (per km2, 2017)                    462.824891     88.1
# Sex ratio (m per 100 f, 2017)                         101.963755     99.0
# GDP: Gross domestic product (million current US$)  324546.512664  20365.0
# GDP growth rate (annual %, const. 2005 prices)          2.508297      2.8
# GDP per capita (current US$)                        14511.252838   5488.2
# Unemployment (% of labour force)                        8.524454      6.6
# International trade: Exports (million US$)          68110.227074   3402.0
# International trade: Imports (million US$)          68971.323144   6103.0
# Population growth rate (average annual %)               1.355022      1.2
# Urban population (% of total population)               59.560262     59.7
# Fertility rate, total (live births per woman)           2.734061      2.2
# Life_Expectancy_Female                                 73.949782     76.5
# Life_Expectancy_Male                                   69.017904     70.7

# %% [markdown]
# #### ii. Dispersion

# %%
dispertion = df[numerical_cols].agg(['std', 'var', 'min', 'max']).T
dispertion['range'] = dispertion['max'] - dispertion['min']

Q1 = df[numerical_cols].quantile(0.25)
Q3 = df[numerical_cols].quantile(0.75)
dispertion['IQR'] = Q3 - Q1

dispertion
# Out:
#                                                             std           var  \
# Surface area (km2)                                 1.787082e+06  3.193663e+12
# Population in thousands (2017)                     1.332751e+05  1.776225e+10
# Population density (per km2, 2017)                 2.305384e+03  5.314797e+06
# Sex ratio (m per 100 f, 2017)                      2.124571e+01  4.513800e+02
# GDP: Gross domestic product (million current US$)  1.478214e+06  2.185115e+12
# GDP growth rate (annual %, const. 2005 prices)     4.614591e+00  2.129445e+01
# GDP per capita (current US$)                       2.326273e+04  5.411546e+08
# Unemployment (% of labour force)                   6.220200e+00  3.869089e+01
# International trade: Exports (million US$)         2.151212e+05  4.627713e+10
# International trade: Imports (million US$)         2.181219e+05  4.757716e+10
# Population growth rate (average annual %)          1.410995e+00  1.990907e+00
# Urban population (% of total population)           2.465817e+01  6.080252e+02
# Fertility rate, total (live births per woman)      1.377186e+00  1.896642e+00
# Life_Expectancy_Female                             8.606131e+00  7.406549e+01
# Life_Expectancy_Male                               7.859227e+00  6.176744e+01
#
#                                                      min         max  \
# Surface area (km2)                                  0.44  17098246.0
# Population in thousands (2017)                      1.00   1409517.0
# Population density (per km2, 2017)                  0.10     25969.8
# Sex ratio (m per 100 f, 2017)                      83.50       301.2
# GDP: Gross domestic product (million current US$)  33.00  18036648.0
# GDP growth rate (annual %, const. 2005 prices)    -28.10        26.3
# GDP per capita (current US$)                       65.00    169491.8
# Unemployment (% of labour force)                    0.30        31.4
# International trade: Exports (million US$)          1.00   2118981.0
# International trade: Imports (million US$)          1.00   2249661.0
# Population growth rate (average annual %)          -2.30         7.0
# Urban population (% of total population)            8.40       100.0
# Fertility rate, total (live births per woman)       1.20         7.4
# Life_Expectancy_Female                             50.70        86.4
# Life_Expectancy_Male                               47.80        81.7
#
#                                                          range       IQR
# Surface area (km2)                                 17098245.56  434574.0
# Population in thousands (2017)                      1409516.00   18762.0
# Population density (per km2, 2017)                    25969.70     186.9
# Sex ratio (m per 100 f, 2017)                           217.70       5.1
# GDP: Gross domestic product (million current US$)  18036615.00  121014.0
# GDP growth rate (annual %, const. 2005 prices)           54.40       3.5
# GDP per capita (current US$)                         169426.80   14901.2
# Unemployment (% of labour force)                         31.10       6.3
# International trade: Exports (million US$)          2118980.00   26944.0
# International trade: Imports (million US$)          2249660.00   34089.0
# Population growth rate (average annual %)                 9.30       1.8
# Urban population (% of total population)                 91.60      39.6
# Fertility rate, total (live births per woman)             6.20       1.8
# Life_Expectancy_Female                                   35.70      12.1
# Life_Expectancy_Male                                     33.90      11.2

# %% [markdown]
# #### iii. Skewness & Kurtosis

# %%
shape = pd.DataFrame({'Skewness':df[numerical_cols].skew(), 'Kurtosis':df[numerical_cols].kurt()})
shape
# Out:
#                                                    Skewness    Kurtosis
# Surface area (km2)                                 6.003574   42.204836
# Population in thousands (2017)                     9.146352   90.003036
# Population density (per km2, 2017)                 9.314745   92.690383
# Sex ratio (m per 100 f, 2017)                      6.794603   52.625720
# GDP: Gross domestic product (million current US$)  9.536977  103.188429
# GDP growth rate (annual %, const. 2005 prices)    -1.761404   15.943680
# GDP per capita (current US$)                       3.493875   16.826263
# Unemployment (% of labour force)                   1.468892    1.930137
# International trade: Exports (million US$)         6.265331   48.132458
# International trade: Imports (million US$)         6.678489   55.252261
# Population growth rate (average annual %)          0.821614    2.201035
# Urban population (% of total population)          -0.126047   -1.030890
# Fertility rate, total (live births per woman)      1.122448    0.360961
# Life_Expectancy_Female                            -0.754338   -0.320607
# Life_Expectancy_Male                              -0.572415   -0.435004

# %% [markdown]
# #### iv) Visualization

# %%
for col in numerical_cols:
    plt.figure(figsize=(16, 4))

    plt.subplot(1, 4, 1)
    sns.histplot(df[col].dropna(), kde=False, color='skyblue')
    plt.title('Histogram')

    plt.subplot(1, 4, 2)
    sns.boxplot(df[col].dropna(), color='salmon')
    plt.title('Boxplot')

    plt.subplot(1, 4, 3)
    sns.kdeplot(df[col].dropna(), fill=True, color='lightgreen')
    plt.title('Density Plot')

    plt.subplot(1, 4, 4)
    sns.violinplot(df[col].dropna(), color='orchid')
    plt.title('Violin Plot')

    plt.suptitle(f'Distribution of {col}', fontsize=16)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### B. Categorical Variables

# %% [markdown]
# #### i. Mode

# %%
mode_region = df['Region'].mode()[0]
print("Most common region:", mode_region)
# Out:
# Most common region: Caribbean

# %% [markdown]
# #### ii. Visualization

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, y='Region', order=df['Region'].value_counts().index, palette='viridis')
plt.title('Number of countries per region')
plt.xlabel('Count')
plt.ylabel('Rgeion')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Bivariate Analysis

# %% [markdown]
# ### A. Numerical vs Numerical
